# %%
# Importing dependencies
import pandas as pd
from sqlalchemy import create_engine
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim
import numpy as np

# %%
# Creating dataframe from csv file
csv_file = "Resources/wine_data.csv"
wine_df=pd.read_csv(csv_file, encoding="utf-8")
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
#Count of non-null records within each column
wine_df.count()
# Out:
# Unnamed: 0               129971
# country                  129908
# description              129971
# designation               92506
# points                   129971
# price                    120975
# province                 129908
# region_1                 108724
# region_2                  50511
# taster_name              103727
# taster_twitter_handle     98758
# title                    129971
# variety                  129970
# winery                   129971
# dtype: int64

# %%
# Resetting index
wine_df.reset_index()
# Removed unnecessary columns (Description and Designation) and created a copy
new_wine_data = wine_df[["country", "points", "price", "province", "region_1", "region_2", "taster_name",\
                        "taster_twitter_handle", "title", "variety", "winery"]].copy()
new_wine_data.head()
# Out:
#     country  points  price           province             region_1  \
# 0     Italy      87    NaN  Sicily & Sardinia                 Etna
# 1  Portugal      87   15.0              Douro                  NaN
# 2        US      87   14.0             Oregon    Willamette Valley
# 3        US      87   13.0           Michigan  Lake Michigan Shore
# 4        US      87   65.0             Oregon    Willamette Valley
#
#             region_2         taster_name taster_twitter_handle  \
# 0                NaN       Kerin O’Keefe          @kerinokeefe
# 1                NaN          Roger Voss            @vossroger
# 2  Willamette Valley        Paul Gregutt           @paulgwine
# 3                NaN  Alexander Peartree                   NaN
# 4  Willamette Valley        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
#Checking if there are duplicated records
new_wine_data[new_wine_data.duplicated(keep=False)]
# Out:
#        country  points  price           province              region_1  \
# 9       France      87   27.0             Alsace                Alsace
# 10          US      87   19.0         California           Napa Valley
# 11      France      87   30.0             Alsace                Alsace
# 12          US      87   34.0         California      Alexander Valley
# 13       Italy      87    NaN  Sicily & Sardinia                  Etna
# ...        ...     ...    ...                ...                   ...
# 129879      US      90   20.0         Washington  Columbia Valley (WA)
# 129880      US      90   20.0         California  Russian River Valley
# 129881   Spain      90   19.0     Northern Spain                 Rueda
# 129882      US      90   60.0         Washington  Columbia Valley (WA)
# 129913      US      92   44.0         Washington  Columbia Valley (WA)
#
#                region_2        taster_name taster_twitter_handle  \
# 9                   NaN         Roger Voss            @vossroger
# 10                 Napa     Virginie Boone               @vboone
# 11                  NaN         Roger Voss            @vossroger
# 12               Sonoma     Virginie Boone               @vboone
# 13                  NaN      Kerin O’Keefe          @kerinokeefe
# ...                 ...                ...                   ...
# 129879  Columbia Valley   Sean P. Sullivan         @wawinereport
# 129880           Sonoma     Virginie Boone               @vboone
# 129881              NaN  Michael Schachner           @wineschach
# 129882  Columbia Valley   Sean P. Sullivan         @wawinereport
# 129913  Columbia Valley       Paul Gregutt           @paulgwine
#
#                                                     title  \
# 9       Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 10      Kirkland Signature 2011 Mountain Cuvée Caberne...
# 11                Leon Beyer 2012 Gewurztraminer (Alsace)
# 12      Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 13                 Masseria Setteporte 2012 Rosso  (Etna)
# ...                                                   ...
# 129879  Maison Bleue 2013 Metis Red (Columbia Valley (...
# 129880  Martin Ray 2015 Chardonnay (Russian River Valley)
# 129881                  Martinsancho 2015 Verdejo (Rueda)
# 129882   Matthews 2012 Reserve Red (Columbia Valley (WA))
# 129913  Woodward Canyon 2005 Artist Series #14 Caberne...
#
#                          variety               winery
# 9                     Pinot Gris   Jean-Baptiste Adam
# 10            Cabernet Sauvignon   Kirkland Signature
# 11                Gewürztraminer           Leon Beyer
# 12            Cabernet Sauvignon     Louis M. Martini
# 13             Nerello Mascalese  Masseria Setteporte
# ...                          ...                  ...
# 129879                 Red Blend         Maison Bleue
# 129880                Chardonnay           Martin Ray
# 129881                   Verdejo         Martinsancho
# 129882  Bordeaux-style Red Blend             Matthews
# 129913        Cabernet Sauvignon      Woodward Canyon
#
# [20125 rows x 11 columns]

# %%
# dropping the duplicate records and keeping the first record
new_wine_data=new_wine_data.drop_duplicates(keep='first')
new_wine_data[new_wine_data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [country, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
# Checking data types for each column
new_wine_data.dtypes
# Out:
# country                   object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
# Finding the number of unique values in each columns
new_wine_data.nunique()
# Out:
# country                      43
# points                       21
# price                       390
# province                    425
# region_1                   1229
# region_2                     17
# taster_name                  19
# taster_twitter_handle        15
# title                    118840
# variety                     707
# winery                    16757
# dtype: int64

# %%
# Check for NaN in country column
new_wine_data[new_wine_data["country"].isna()==True]
# Out:
#        country  points  price province region_1 region_2        taster_name  \
# 913        NaN      87   30.0      NaN      NaN      NaN      Mike DeSimone
# 3131       NaN      83    NaN      NaN      NaN      NaN         Roger Voss
# 4243       NaN      88   18.0      NaN      NaN      NaN      Mike DeSimone
# 9509       NaN      92   28.0      NaN      NaN      NaN    Susan Kostrzewa
# 9750       NaN      89   28.0      NaN      NaN      NaN       Jeff Jenssen
# 11150      NaN      89   20.0      NaN      NaN      NaN       Jeff Jenssen
# 11348      NaN      82    NaN      NaN      NaN      NaN         Roger Voss
# 14030      NaN      88   25.0      NaN      NaN      NaN       Jeff Jenssen
# 16000      NaN      86   40.0      NaN      NaN      NaN  Michael Schachner
# 16749      NaN      91    NaN      NaN      NaN      NaN      Lauren Buzzeo
# 18075      NaN      90   17.0      NaN      NaN      NaN    Susan Kostrzewa
# 26485      NaN      87   13.0      NaN      NaN      NaN       Jeff Jenssen
# 26486      NaN      87   14.0      NaN      NaN      NaN      Mike DeSimone
# 26489      NaN      87   12.0      NaN      NaN      NaN  Michael Schachner
# 27822      NaN      86   19.0      NaN      NaN      NaN     Joe Czerwinski
# 36112      NaN      89   25.0      NaN      NaN      NaN       Jeff Jenssen
# 38240      NaN      89   24.0      NaN      NaN      NaN   Anne Krebiehl MW
# 38898      NaN      89   34.0      NaN      NaN      NaN       Paul Gregutt
# 44674      NaN      91   25.0      NaN      NaN      NaN   Anne Krebiehl MW
# 44850      NaN      84    6.0      NaN      NaN      NaN       Jeff Jenssen
# 44851      NaN      84    6.0      NaN      NaN      NaN       Jeff Jenssen
# 45247      NaN      89   25.0      NaN      NaN      NaN   Anne Krebiehl MW
# 45402      NaN      85   12.0      NaN      NaN      NaN  Michael Schachner
# 46352      NaN      91   50.0      NaN      NaN      NaN  Michael Schachner
# 49425      NaN      88   28.0      NaN      NaN      NaN       Jeff Jenssen
# 49426      NaN      88   28.0      NaN      NaN      NaN       Jeff Jenssen
# 49427      NaN      88   19.0      NaN      NaN      NaN       Jeff Jenssen
# 49510      NaN      91   34.0      NaN      NaN      NaN      Mike DeSimone
# 54222      NaN      87   30.0      NaN      NaN      NaN      Mike DeSimone
# 57612      NaN      92    NaN      NaN      NaN      NaN      Lauren Buzzeo
# 59670      NaN      92   38.0      NaN      NaN      NaN   Anne Krebiehl MW
# 60678      NaN      86   17.0      NaN      NaN      NaN    Susan Kostrzewa
# 66524      NaN      88   25.0      NaN      NaN      NaN      Mike DeSimone
# 68322      NaN      89   20.0      NaN      NaN      NaN       Jeff Jenssen
# 72581      NaN      89   21.0      NaN      NaN      NaN       Jeff Jenssen
# 79270      NaN      86   11.0      NaN      NaN      NaN       Jeff Jenssen
# 81955      NaN      89   16.0      NaN      NaN      NaN       Jeff Jenssen
# 81957      NaN      89   18.0      NaN      NaN      NaN       Jeff Jenssen
# 85602      NaN      88   36.0      NaN      NaN      NaN      Lauren Buzzeo
# 85603      NaN      88   23.0      NaN      NaN      NaN       Jeff Jenssen
# 85821      NaN      90   22.0      NaN      NaN      NaN   Anne Krebiehl MW
# 90146      NaN      89   16.0      NaN      NaN      NaN       Jeff Jenssen
# 90151      NaN      89   25.0      NaN      NaN      NaN       Jeff Jenssen
# 95176      NaN      91   38.0      NaN      NaN      NaN   Anne Krebiehl MW
# 97850      NaN      89   17.0      NaN      NaN      NaN   Anne Krebiehl MW
# 98094      NaN      89   24.0      NaN      NaN      NaN       Jeff Jenssen
# 100570     NaN      87   37.0      NaN      NaN      NaN    Susan Kostrzewa
# 100722     NaN      89   25.0      NaN      NaN      NaN       Jeff Jenssen
# 105167     NaN      92   21.0      NaN      NaN      NaN   Anne Krebiehl MW
# 105715     NaN      92   50.0      NaN      NaN      NaN      Mike DeSimone
# 113520     NaN      90   22.0      NaN      NaN      NaN  Michael Schachner
# 119787     NaN      90   30.0      NaN      NaN      NaN      Mike DeSimone
# 120248     NaN      92   36.0      NaN      NaN      NaN      Mike DeSimone
# 120799     NaN      90   27.0      NaN      NaN      NaN    Susan Kostrzewa
# 124176     NaN      90   30.0      NaN      NaN      NaN       Jeff Jenssen
# 129407     NaN      89   22.0      NaN      NaN      NaN  Michael Schachner
# 129408     NaN      89   22.0      NaN      NaN      NaN  Michael Schachner
# 129590     NaN      90   30.0      NaN      NaN      NaN      Mike DeSimone
# 129900     NaN      91   32.0      NaN      NaN      NaN      Mike DeSimone
#
#        taster_twitter_handle  \
# 913           @worldwineguys
# 3131              @vossroger
# 4243          @worldwineguys
# 9509           @suskostrzewa
# 9750          @worldwineguys
# 11150         @worldwineguys
# 11348             @vossroger
# 14030         @worldwineguys
# 16000            @wineschach
# 16749              @laurbuzz
# 18075          @suskostrzewa
# 26485         @worldwineguys
# 26486         @worldwineguys
# 26489            @wineschach
# 27822                 @JoeCz
# 36112         @worldwineguys
# 38240            @AnneInVino
# 38898            @paulgwine
# 44674            @AnneInVino
# 44850         @worldwineguys
# 44851         @worldwineguys
# 45247            @AnneInVino
# 45402            @wineschach
# 46352            @wineschach
# 49425         @worldwineguys
# 49426         @worldwineguys
# 49427         @worldwineguys
# 49510         @worldwineguys
# 54222         @worldwineguys
# 57612              @laurbuzz
# 59670            @AnneInVino
# 60678          @suskostrzewa
# 66524         @worldwineguys
# 68322         @worldwineguys
# 72581         @worldwineguys
# 79270         @worldwineguys
# 81955         @worldwineguys
# 81957         @worldwineguys
# 85602              @laurbuzz
# 85603         @worldwineguys
# 85821            @AnneInVino
# 90146         @worldwineguys
# 90151         @worldwineguys
# 95176            @AnneInVino
# 97850            @AnneInVino
# 98094         @worldwineguys
# 100570         @suskostrzewa
# 100722        @worldwineguys
# 105167           @AnneInVino
# 105715        @worldwineguys
# 113520           @wineschach
# 119787        @worldwineguys
# 120248        @worldwineguys
# 120799         @suskostrzewa
# 124176        @worldwineguys
# 129407           @wineschach
# 129408           @wineschach
# 129590        @worldwineguys
# 129900        @worldwineguys
#
#                                                     title  \
# 913        Gotsa Family Wines 2014 Asureti Valley Chinuri
# 3131                    Barton & Guestier NV Partager Red
# 4243    Kakhetia Traditional Winemaking 2012 Red Natur...
# 9509    Tsililis 2015 Theopetra Malagouzia-Assyrtiko W...
# 9750    Ross-idi 2015 Orange Nikolaevo Vineyard Chardo...
# 11150                                 Orbelus 2013 Melnik
# 11348                 Barton & Guestier NV Partager White
# 14030                          St. Donat 2013 Márga White
# 16000   Familia Deicas 2015 Valle de los Manantiales V...
# 16749   Bartho Eksteen 2016 Cape Winemakers Guild Vloe...
# 18075                   Tsililis 2015 Askitikos Assyrtiko
# 26485                            Stone Castle 2013 Shiraz
# 26486                      Teliani Valley 2015 Tsolikouri
# 26489       Undurraga 2016 Aliwen Reserva Sauvignon Blanc
# 27822                       Mt. Beautiful 2014 Pinot Gris
# 36112   Orbelus 2012 Hrumki Melnik 55 Mourvèdre Marsel...
# 38240    Neumeister 2015 Steirische Klassik Grauburgunder
# 38898     Bachelder 2014 Wismer-Parke Vineyard Pinot Noir
# 44674    Neumeister 2016 Steirische Klassik Grauburgunder
# 44850                       Stone Castle 2014 Amphora Red
# 44851                    Stone Castle 2015 Royal Riesling
# 45247   Neumeister 2016 Steirische Klassik Sauvignon B...
# 45402      Chilcas 2015 Reserva Estate Bottled Pinot Noir
# 46352                         Santa Ema 2014 Catalina Red
# 49425    Orbelus 2011 Getika Made With Organic Grapes Red
# 49426    Orbelus 2012 Getika Made With Organic Grapes Red
# 49427   Orbelus 2013 Hrumki Syrah Melnik 55 Mourvèdre ...
# 49510                      Psagot 2013 Cabernet Sauvignon
# 54222    Gotsa Family Wines 2013 Babaneuri Valley Mtsvane
# 57612   Newton Johnson 2016 Cape Winemakers Guild Wind...
# 59670             Neumeister 2015 Steintal Roter Traminer
# 60678                         Ktima Voyatzi 2015 Dry Rosé
# 66524   Gotsa Family Wines 2015 Dry Unfiltered Rkatsit...
# 68322                  Ross-idi 2015 Nikolaevo Chardonnay
# 72581                       St. Donat 2014 Estate Furmint
# 79270                    Stone Castle 2014 Premium Vranac
# 81955   Ross-idi 2014 Nikolaevo Unison Chardonnay-Gewü...
# 81957                        St. Donat 2015 Márga Furmint
# 85602                             Lismore 2014 Chardonnay
# 85603                          Logodaj 2013 Nobile Melnik
# 85821         Neumeister 2015 Steirische Klassik Morillon
# 90146     Ross-idi 2015 Nikolaevo Vineyard Gewürztraminer
# 90151                          Somlói Vándor 2015 Furmint
# 95176             Neumeister 2015 Klausen Sauvignon Blanc
# 97850               Neumeister 2016 Gemischter Satz White
# 98094        Orbelus 2013 Made With Organic Grapes Melnik
# 100570                 Tsililis 2012 Theopetra Estate Red
# 100722  Les Frères Dutruy 2014 Domaine de la Treille P...
# 105167  Neumeister 2016 Steirische Klassik Gelber Musk...
# 105715                               Psagot 2014 Peak Red
# 113520                    El Capricho 2015 Reserve Tannat
# 119787           Amiran Vepkhvadze 2014 Otskhanuri Sapere
# 120248                Psagot 2013 M Series Cabernet Franc
# 120799                    Ktima Voyatzi 2014 Tsapournakos
# 124176            Les Frères Dutruy 2014 Les Romaines Red
# 129407        El Capricho 2015 Reserve Cabernet Sauvignon
# 129408               El Capricho 2015 Reserve Tempranillo
# 129590                            Büyülübağ 2012 Shah Red
# 129900                                 Psagot 2014 Merlot
#
#                       variety                           winery
# 913                   Chinuri               Gotsa Family Wines
# 3131                Red Blend                Barton & Guestier
# 4243                 Ojaleshi  Kakhetia Traditional Winemaking
# 9509              White Blend                         Tsililis
# 9750               Chardonnay                         Ross-idi
# 11150                  Melnik                          Orbelus
# 11348             White Blend                Barton & Guestier
# 14030             White Blend                        St. Donat
# 16000                  Tannat                   Familia Deicas
# 16749         Sauvignon Blanc                   Bartho Eksteen
# 18075               Assyrtiko                         Tsililis
# 26485                  Shiraz                     Stone Castle
# 26486              Tsolikouri                   Teliani Valley
# 26489         Sauvignon Blanc                        Undurraga
# 27822              Pinot Gris                    Mt. Beautiful
# 36112               Red Blend                          Orbelus
# 38240           Grauburgunder                       Neumeister
# 38898              Pinot Noir                        Bachelder
# 44674           Grauburgunder                       Neumeister
# 44850               Red Blend                     Stone Castle
# 44851                Riesling                     Stone Castle
# 45247         Sauvignon Blanc                       Neumeister
# 45402              Pinot Noir                          Chilcas
# 46352               Red Blend                        Santa Ema
# 49425               Red Blend                          Orbelus
# 49426               Red Blend                          Orbelus
# 49427               Red Blend                          Orbelus
# 49510      Cabernet Sauvignon                           Psagot
# 54222                 Mtsvane               Gotsa Family Wines
# 57612              Pinot Noir                   Newton Johnson
# 59670          Roter Traminer                       Neumeister
# 60678                    Rosé                    Ktima Voyatzi
# 66524             White Blend               Gotsa Family Wines
# 68322              Chardonnay                         Ross-idi
# 72581                 Furmint                        St. Donat
# 79270                  Vranac                     Stone Castle
# 81955             White Blend                         Ross-idi
# 81957                 Furmint                        St. Donat
# 85602              Chardonnay                          Lismore
# 85603                  Melnik                          Logodaj
# 85821                Morillon                       Neumeister
# 90146          Gewürztraminer                         Ross-idi
# 90151                 Furmint                    Somlói Vándor
# 95176         Sauvignon Blanc                       Neumeister
# 97850    Austrian white blend                       Neumeister
# 98094                  Melnik                          Orbelus
# 100570              Red Blend                         Tsililis
# 100722             Pinot Gris                Les Frères Dutruy
# 105167     Gelber Muskateller                       Neumeister
# 105715  Rhône-style Red Blend                           Psagot
# 113520                 Tannat                      El Capricho
# 119787      Otskhanuri Sapere                Amiran Vepkhvadze
# 120248         Cabernet Franc                           Psagot
# 120799           Tsapournakos                    Ktima Voyatzi
# 124176              Red Blend                Les Frères Dutruy
# 129407     Cabernet Sauvignon                      El Capricho
# 129408            Tempranillo                      El Capricho
# 129590              Red Blend                        Büyülübağ
# 129900                 Merlot                           Psagot

# %%
# Dropped null records in country column
new_wine_data=new_wine_data.loc[(new_wine_data["country"].isna()==False),:]
new_wine_data.head()
# Out:
#     country  points  price           province             region_1  \
# 0     Italy      87    NaN  Sicily & Sardinia                 Etna
# 1  Portugal      87   15.0              Douro                  NaN
# 2        US      87   14.0             Oregon    Willamette Valley
# 3        US      87   13.0           Michigan  Lake Michigan Shore
# 4        US      87   65.0             Oregon    Willamette Valley
#
#             region_2         taster_name taster_twitter_handle  \
# 0                NaN       Kerin O’Keefe          @kerinokeefe
# 1                NaN          Roger Voss            @vossroger
# 2  Willamette Valley        Paul Gregutt           @paulgwine
# 3                NaN  Alexander Peartree                   NaN
# 4  Willamette Valley        Paul Gregutt           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
#Checking if null values in country column has been dropped
new_wine_data["country"].isna().sum()
# Out:
# 0

# %%
#Creating a year column from title column
new_wine_data["year"]=new_wine_data["title"].str.extract('(\s[0-9]{4}\s)')
new_wine_data["year"]=new_wine_data["year"].str.strip()
new_wine_data.head(50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61c130e83455> in <module>
#       1 #Creating a year column from title column
# ----> 2 new_wine_data["year"]=new_wine_data["title"].str.extract('(\s[0-9]{4}\s)')
#       3 new_wine_data["year"]=new_wine_data["year"].str.strip()
#       4 new_wine_data.head(50)
#
# NameError: name 'new_wine_data' is not defined

# %%
new_wine_data.count()
# Out:
# country                  119841
# points                   119841
# price                    111453
# province                 119841
# region_1                 100344
# region_2                  46754
# taster_name               94942
# taster_twitter_handle     90415
# title                    119841
# variety                  119840
# winery                   119841
# year                     115651
# dtype: int64

# %%
#Creating a location column by combining country, province, region_1, region_2
new_wine_data["location"]=new_wine_data["region_1"].fillna('-').map(str)\
+ ", "+ new_wine_data["region_2"].fillna('-')\
+ ", "+ new_wine_data["province"].fillna('-')\
+ ", "+ new_wine_data["country"]

new_wine_data.count()
# Out:
# country                  119841
# points                   119841
# price                    111453
# province                 119841
# region_1                 100344
# region_2                  46754
# taster_name               94942
# taster_twitter_handle     90415
# title                    119841
# variety                  119840
# winery                   119841
# year                     115651
# location                 119841
# dtype: int64

# %%
#URL to fetch secondary data- grape variety by color
url="https://en.wikipedia.org/wiki/List_of_grape_varieties#Red_table_grapes"

# %%
#Reading the data from html into a list of tables
tables=pd.read_html(url)

# %%
#Creating data frames for each grape color
#Dataframe for red grapes
grapes_red_df=tables[0]
#Dataframe for white grapes
grapes_white_df=tables[1]
#Dataframe for rose' grapes
grapes_rose_df=tables[2]

# %%
#Assigning the grape_color column for red grapes
grapes_red_df["grape_color"]="red"

#Assigning the grape_color column for white grapes
grapes_white_df["grape_color"]="white"

#Assigning the grape_color column for rose
grapes_rose_df["grape_color"]="rose"

# %%
#Combining the three different grape color dataframes into one 
grape_color_df=pd.concat([grapes_red_df,grapes_white_df,grapes_rose_df])
grape_color_df=grape_color_df[["Common Name(s)","grape_color"]]
grape_color_df["grape_color"].value_counts()
# Out:
# red      426
# white    394
# rose       2
# Name: grape_color, dtype: int64

# %%
#Dropping duplicated records
grape_color_df=grape_color_df.drop_duplicates()
#Finding if we have multiple records with same grape but different color
grape_color_df[grape_color_df.duplicated(subset=["Common Name(s)"],keep=False)]
#grape_color_df[grape_color_df["Common Name(s)"]=='Alexandroouli']
# Out:
#     Common Name(s) grape_color
# 34      Arnsburger         red
# 156         Cereza         red
# 222     Grignolino         red
# 332       Pignerol         red
# 368    Schönburger         red
# 27      Arnsburger       white
# 87          Cereza       white
# 170     Grignolino       white
# 275       Pignerol       white
# 320    Schönburger       white

# %%
#Dropping duplicate records based on Common Name(s) and keeping only the first record
grape_color_df=grape_color_df.drop_duplicates(subset='Common Name(s)', keep="first")
grape_color_df[grape_color_df.duplicated(subset=["Common Name(s)"],keep=False)]
# Out:
# Empty DataFrame
# Columns: [Common Name(s), grape_color]
# Index: []

# %%
# Merging wine dataframe with grape color dataframe
wine_review_df=new_wine_data.merge(grape_color_df, left_on="variety",right_on="Common Name(s)",how="left")

# %%
#Creating a wine review dataframe with the grape color column added for red color grapes
wine_review_df=wine_review_df[["country", "points", "price", "province", "region_1", "region_2","location", "taster_name",\
                        "taster_twitter_handle", "title","year","variety", "winery","grape_color"]]

# %%
#Checking for null values in the grape_color column
wine_review_df[wine_review_df["grape_color"].isna()==True]
# Out:
#          country  points  price           province             region_1  \
# 0          Italy      87    NaN  Sicily & Sardinia                 Etna
# 1       Portugal      87   15.0              Douro                  NaN
# 2             US      87   14.0             Oregon    Willamette Valley
# 3             US      87   13.0           Michigan  Lake Michigan Shore
# 4             US      87   65.0             Oregon    Willamette Valley
# ...          ...     ...    ...                ...                  ...
# 119836   Germany      90   28.0              Mosel                  NaN
# 119837        US      90   75.0             Oregon               Oregon
# 119838    France      90   30.0             Alsace               Alsace
# 119839    France      90   32.0             Alsace               Alsace
# 119840    France      90   21.0             Alsace               Alsace
#
#                  region_2                                          location  \
# 0                     NaN                 Etna, -, Sicily & Sardinia, Italy
# 1                     NaN                             -, -, Douro, Portugal
# 2       Willamette Valley  Willamette Valley, Willamette Valley, Oregon, US
# 3                     NaN              Lake Michigan Shore, -, Michigan, US
# 4       Willamette Valley  Willamette Valley, Willamette Valley, Oregon, US
# ...                   ...                                               ...
# 119836                NaN                              -, -, Mosel, Germany
# 119837       Oregon Other                  Oregon, Oregon Other, Oregon, US
# 119838                NaN                         Alsace, -, Alsace, France
# 119839                NaN                         Alsace, -, Alsace, France
# 119840                NaN                         Alsace, -, Alsace, France
#
#                taster_name taster_twitter_handle  \
# 0            Kerin O’Keefe          @kerinokeefe
# 1               Roger Voss            @vossroger
# 2             Paul Gregutt           @paulgwine
# 3       Alexander Peartree                   NaN
# 4             Paul Gregutt           @paulgwine
# ...                    ...                   ...
# 119836  Anna Lee C. Iijima                   NaN
# 119837        Paul Gregutt           @paulgwine
# 119838          Roger Voss            @vossroger
# 119839          Roger Voss            @vossroger
# 119840          Roger Voss            @vossroger
#
#                                                     title  year  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)  2013
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  2011
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)  2013
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...  2013
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...  2012
# ...                                                   ...   ...
# 119836  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...  2013
# 119837                  Citation 2004 Pinot Noir (Oregon)  2004
# 119838  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  2013
# 119839      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)  2012
# 119840  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  2012
#
#                variety                                    winery grape_color
# 0          White Blend                                   Nicosia         NaN
# 1       Portuguese Red                       Quinta dos Avidagos         NaN
# 2           Pinot Gris                                 Rainstorm         NaN
# 3             Riesling                                St. Julian         NaN
# 4           Pinot Noir                              Sweet Cheeks         NaN
# ...                ...                                       ...         ...
# 119836        Riesling  Dr. H. Thanisch (Erben Müller-Burggraef)         NaN
# 119837      Pinot Noir                                  Citation         NaN
# 119838  Gewürztraminer                           Domaine Gresser         NaN
# 119839      Pinot Gris                      Domaine Marcel Deiss         NaN
# 119840  Gewürztraminer                          Domaine Schoffit         NaN
#
# [83866 rows x 14 columns]

# %%
#Checking the count of values for each grape color
wine_review_df["grape_color"].value_counts()
# Out:
# red      21201
# white    14774
# Name: grape_color, dtype: int64

# %%
#Rename columns in the data set to match column names in the table
wine_review_df.columns=["country_name","wine_score","wine_price","province","region1","region2",\
                        "combined_region","taster_name","taster_twitter","wine_name","wine_year","grape_name",\
                        "winery_name", "grape_color"]

# %%
wine_review_df.head()
# Out:
#   country_name  wine_score  wine_price           province  \
# 0        Italy          87         NaN  Sicily & Sardinia
# 1     Portugal          87        15.0              Douro
# 2           US          87        14.0             Oregon
# 3           US          87        13.0           Michigan
# 4           US          87        65.0             Oregon
#
#                region1            region2  \
# 0                 Etna                NaN
# 1                  NaN                NaN
# 2    Willamette Valley  Willamette Valley
# 3  Lake Michigan Shore                NaN
# 4    Willamette Valley  Willamette Valley
#
#                                     combined_region         taster_name  \
# 0                 Etna, -, Sicily & Sardinia, Italy       Kerin O’Keefe
# 1                             -, -, Douro, Portugal          Roger Voss
# 2  Willamette Valley, Willamette Valley, Oregon, US        Paul Gregutt
# 3              Lake Michigan Shore, -, Michigan, US  Alexander Peartree
# 4  Willamette Valley, Willamette Valley, Oregon, US        Paul Gregutt
#
#   taster_twitter                                          wine_name wine_year  \
# 0   @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)      2013
# 1     @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)      2011
# 2    @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)      2013
# 3            NaN  St. Julian 2013 Reserve Late Harvest Riesling ...      2013
# 4    @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...      2012
#
#        grape_name          winery_name grape_color
# 0     White Blend              Nicosia         NaN
# 1  Portuguese Red  Quinta dos Avidagos         NaN
# 2      Pinot Gris            Rainstorm         NaN
# 3        Riesling           St. Julian         NaN
# 4      Pinot Noir         Sweet Cheeks         NaN

# %%
#Checking integrity of new wine review data set
wine_review_df.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# dtype: int64

# %%
#Check for duplicated records
wine_review_df[wine_review_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country_name, wine_score, wine_price, province, region1, region2, combined_region, taster_name, taster_twitter, wine_name, wine_year, grape_name, winery_name, grape_color]
# Index: []

# %%
wine_review_df.nunique()
# Out:
# country_name           43
# wine_score             21
# wine_price            390
# province              425
# region1              1229
# region2                17
# combined_region      1619
# taster_name            19
# taster_twitter         15
# wine_name          118781
# wine_year              82
# grape_name            701
# winery_name         16745
# grape_color             2
# dtype: int64

# %%
#Finding max length of data in each column in the dataframe so that the column length in tables can be gauged

dict([(v, wine_review_df[v].apply(lambda r: len(str(r)) if r!=None else 0).max())for v in wine_review_df.columns.values])
# Out:
# {'country_name': 22,
#  'wine_score': 3,
#  'wine_price': 6,
#  'province': 31,
#  'region1': 50,
#  'region2': 17,
#  'combined_region': 84,
#  'taster_name': 18,
#  'taster_twitter': 16,
#  'wine_name': 136,
#  'wine_year': 4,
#  'grape_name': 35,
#  'winery_name': 54,
#  'grape_color': 5}

# %% [markdown]
# ### Creating master tables for loading

# %%
#Creating country_df that will be used to load country table into the database
country_df=pd.DataFrame(wine_review_df["country_name"].unique())

#Set index to start at 1
country_df.index = country_df.index + 1

# %%
#Resetting the index to create primary key for table
country_df=country_df.reset_index()

# %%
#Renaming columns to match column names in country table
country_df.columns=["country_id","country_name"]
country_df.nunique()
# Out:
# country_id      43
# country_name    43
# dtype: int64

# %%
#Creating taster_df that will be used to load taster table into the database
taster_df=wine_review_df[["taster_name", "taster_twitter"]].drop_duplicates().reset_index().drop(columns=["index"])

#Set index to start at 1
taster_df.index = taster_df.index + 1

# %%
#Resetting the index to create primary key for table
taster_df=taster_df.reset_index()

# %%
#Renaming columns to match column names in taster table
taster_df.columns=["taster_id","taster_name","taster_twitter"]
taster_df.nunique()
# Out:
# taster_id         20
# taster_name       19
# taster_twitter    15
# dtype: int64

# %%
taster_df
# Out:
#     taster_id         taster_name    taster_twitter
# 0           1       Kerin O’Keefe      @kerinokeefe
# 1           2          Roger Voss        @vossroger
# 2           3        Paul Gregutt       @paulgwine
# 3           4  Alexander Peartree               NaN
# 4           5   Michael Schachner       @wineschach
# 5           6  Anna Lee C. Iijima               NaN
# 6           7      Virginie Boone           @vboone
# 7           8       Matt Kettmann     @mattkettmann
# 8           9                 NaN               NaN
# 9          10    Sean P. Sullivan     @wawinereport
# 10         11          Jim Gordon  @gordone_cellars
# 11         12      Joe Czerwinski            @JoeCz
# 12         13    Anne Krebiehl MW       @AnneInVino
# 13         14       Lauren Buzzeo         @laurbuzz
# 14         15       Mike DeSimone    @worldwineguys
# 15         16        Jeff Jenssen    @worldwineguys
# 16         17     Susan Kostrzewa     @suskostrzewa
# 17         18        Carrie Dykes               NaN
# 18         19         Fiona Adams          @bkfiona
# 19         20   Christina Pickard   @winewchristina

# %%
#Creating winery_df that will be used to load winery table into the database
winery_df=wine_review_df[["winery_name"]].drop_duplicates().reset_index().drop(columns=["index"])

#Set index to start at 1
winery_df.index = winery_df.index + 1

# %%
#Resetting the index to create primary key for table
winery_df=winery_df.reset_index()

# %%
#Renaming columns to match column names in winery table
winery_df.columns=["winery_id","winery_name"]
winery_df.nunique()
# Out:
# winery_id      16745
# winery_name    16745
# dtype: int64

# %%
#Creating grape_variety_df that will be used to load grape_variety table into the database
grape_variety_df=wine_review_df[["grape_name","grape_color"]].drop_duplicates().reset_index().drop(columns=["index"])

#Set index to start at 1
grape_variety_df.index = grape_variety_df.index + 1

# %%
#Resetting the index to create primary key for table
grape_variety_df=grape_variety_df.reset_index()

# %%
#Renaming columns to match column names in winery table
grape_variety_df.columns=["grape_id","grape_name","grape_color"]
grape_variety_df.nunique()
# Out:
# grape_id       702
# grape_name     701
# grape_color      2
# dtype: int64

# %%
#Creating region_df that will be used to load region table into the database
region_df=wine_review_df[["country_name","province","region1","region2","combined_region"]].drop_duplicates()\
.reset_index().drop(columns=["index"])

#Set index to start at 1
region_df.index = region_df.index + 1

# %%
#Resetting the index to create primary key for table
region_df=region_df.reset_index()

# %%
#Renaming columns to match column names in region table
region_df.columns=["region_id","country_name","province","region1","region2","combined_region"]
region_df.nunique()
# Out:
# region_id          1619
# country_name         43
# province            425
# region1            1229
# region2              17
# combined_region    1619
# dtype: int64

# %%
#Creating a province dataframe of unique provinces and will be used to find latitude and longitudes for the provinces
province_df=pd.DataFrame(region_df["province"].unique())
province_df.columns=["province"]
province_df.head()
# Out:
#             province
# 0  Sicily & Sardinia
# 1              Douro
# 2             Oregon
# 3           Michigan
# 4     Northern Spain

# %%
# Calculating latitude and longtitude for provinces in province dataframe and assigning to latitude and longitude list

longitude = [] 
latitude = [] 
   
# function to find the coordinate 
# of a given city  
def findGeocode(province): 
       
    # try and catch is used to overcome 
    # the exception thrown by geolocator 
    # using geocodertimedout   
    #try: 
          
    # Specify the user_agent as your 
    # app name it should not be none 
    geolocator = Nominatim(user_agent="wine_review") 

    return geolocator.geocode(province,timeout=None) 
      
    #except GeocoderTimedOut: 
          
        #return findGeocode(province)     
  
    # each value from city column 
    # will be fetched and sent to 
    # function find_geocode    
for i in (province_df["province"]): 
      
    if findGeocode(i) != None: 
           
        loc = findGeocode(i) 
          
        # coordinates returned from  
        # function is stored into 
        # two separate list 
        latitude.append(loc.latitude) 
        longitude.append(loc.longitude) 
       
    # if coordinate for a city not 
    # found, insert "NaN" indicating  
    # missing value  
    else: 
        latitude.append(np.nan) 
        longitude.append(np.nan)

# %%
#Assigning latitudes and longitudes created for province to respective columns in province dataframe
province_df["latitude"]=latitude
province_df["longitude"]=latitude

# %%
#Merging region and province dataframe to add latitude and longitude columns to region dataframe
region_df=region_df.merge(region_df.merge(province_df, how='inner', on='province', sort=False))
region_df.nunique()
# Out:
# region_id          1619
# country_name         43
# province            425
# region1            1229
# region2              17
# combined_region    1619
# latitude            372
# longitude           372
# dtype: int64

# %%
#Merging region and country dataframe to add country_id column to region dataframe and dropping country_name column
region_df=region_df.merge(region_df.merge(country_df, how='inner', on='country_name', sort=False))\
.drop(columns=["country_name"])

# %%
region_df.nunique()
# Out:
# region_id          1619
# province            425
# region1            1229
# region2              17
# combined_region    1619
# latitude            372
# longitude           372
# country_id           43
# dtype: int64

# %%
wine_review_df.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# dtype: int64

# %%
#Creating wine_review_data_df dataframe from wine_review_df dataframe and adding references to other dataframe

#Adding grape_id column in wine_review_data_df which is referenced to grape dataframe
wine_review_data_df=wine_review_df.merge(grape_variety_df,on=["grape_name","grape_color"],sort=False)
wine_review_data_df.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# grape_id           119841
# dtype: int64

# %%
#Adding region_id column in wine_review_data_df which is referenced to region dataframe
wine_review_data_df=wine_review_data_df.merge(region_df[["region_id","combined_region"]]\
                                                              ,on="combined_region",sort=False)
wine_review_data_df.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# grape_id           119841
# region_id          119841
# dtype: int64

# %%
#Adding taster_id column in wine_review_data_df which is referenced to taster dataframe
wine_review_data_df=wine_review_data_df.merge(taster_df,on=["taster_name","taster_twitter"],sort=False)
wine_review_data_df.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# grape_id           119841
# region_id          119841
# taster_id          119841
# dtype: int64

# %%
#Adding winery_id column in wine_review_data_df which is referenced to winery dataframe
final_wine_data=pd.merge(wine_review_data_df, winery_df, on="winery_name", how="inner", sort=False)
final_wine_data.count()
# Out:
# country_name       119841
# wine_score         119841
# wine_price         111453
# province           119841
# region1            100344
# region2             46754
# combined_region    119841
# taster_name         94942
# taster_twitter      90415
# wine_name          119841
# wine_year          115651
# grape_name         119840
# winery_name        119841
# grape_color         35975
# grape_id           119841
# region_id          119841
# taster_id          119841
# winery_id          119841
# dtype: int64

# %%
final_wine_review_df=final_wine_data[["wine_name","wine_year","wine_price","wine_score",\
                                 "grape_id","region_id","taster_id","winery_id"]].drop_duplicates()\
.reset_index().drop(columns=["index"])

#Set index to start at 1
final_wine_review_df.index = final_wine_review_df.index + 1

# %%
final_wine_review_df=final_wine_review_df.reset_index()

# %%
final_wine_review_df.columns=["wine_review_id","wine_name","wine_year","wine_price","wine_score",\
                                 "grape_id","region_id","taster_id","winery_id"]

# %%
final_wine_review_df.dtypes
# Out:
# wine_review_id      int64
# wine_name          object
# wine_year          object
# wine_price        float64
# wine_score          int64
# grape_id            int64
# region_id           int64
# taster_id           int64
# winery_id           int64
# dtype: object

# %%
final_wine_review_df.head()
# Out:
#    wine_review_id                                          wine_name  \
# 0               1                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1               2           Nicosia 2013 Fondo Filara Bianco  (Etna)
# 2               3                         Nicosia 2011 Rosso  (Etna)
# 3               4                   Nicosia 2012 Vulkà Rosso  (Etna)
# 4               5  Nicosia 2011 Fondo Filara  (Cerasuolo di Vitto...
#
#   wine_year  wine_price  wine_score  grape_id  region_id  taster_id  winery_id
# 0      2013         NaN          87         1          1          1          1
# 1      2013         NaN          88         1          1          1          1
# 2      2011         NaN          87        15          1          1          1
# 3      2012         NaN          91        15          1          1          1
# 4      2011        15.0          90        15        522          1          1

# %% [markdown]
# ## Connect to database

# %%
rds_connection_string = "postgres:postgres@localhost:5433/wine_review_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %% [markdown]
# ## Check for Tables

# %%
engine.table_names()
# Out:
# ['grape_variety', 'region', 'taster', 'winery', 'country', 'wine_review']

# %% [markdown]
# ## Inserting data into tables

# %%
#Inserting data into country table
country_df.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
#Inserting data into taster table
taster_df.to_sql(name='taster', con=engine, if_exists='append', index=False)

# %%
#Inserting data into winery table
winery_df.to_sql(name='winery', con=engine, if_exists='append', index=False)

# %%
#Inserting data into grape_variety table
grape_variety_df.to_sql(name='grape_variety', con=engine, if_exists='append', index=False)

# %%
#Inserting data into region table
region_df.to_sql(name='region', con=engine, if_exists='append', index=False)

# %%
#Inserting data into wine_review table
final_wine_review_df.to_sql(name='wine_review', con=engine, if_exists='append', index=False)
